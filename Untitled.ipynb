# %%
import itertools as it

# %%
cols = ['nspn_id', 'occ' ]

hemi_list = ['lh', 'rh']

parc_list = ['aparc', '500.aparc', 'lobesStrict',
             'Yeo2011_7Networks_N1000', 'HCP', 'economo']

measure_list = ['MT', 'R1', 'R2s', 'A',
                'FA', 'MD', 'L1', 'L23', 'MO']

columns = cols + [ '{}_{}_{}'.format(hemi, parc, measure) 
                    for hemi, parc, measure in it.product(hemi_list, parc_list, measure_list) ]

# %%
columns
# Out:
# ['nspn_id',
#  'occ',
#  'lh_aparc_MT',
#  'lh_aparc_R1',
#  'lh_aparc_R2s',
#  'lh_aparc_A',
#  'lh_aparc_FA',
#  'lh_aparc_MD',
#  'lh_aparc_L1',
#  'lh_aparc_L23',
#  'lh_aparc_MO',
#  'lh_500.aparc_MT',
#  'lh_500.aparc_R1',
#  'lh_500.aparc_R2s',
#  'lh_500.aparc_A',
#  'lh_500.aparc_FA',
#  'lh_500.aparc_MD',
#  'lh_500.aparc_L1',
#  'lh_500.aparc_L23',
#  'lh_500.aparc_MO',
#  'lh_lobesStrict_MT',
#  'lh_lobesStrict_R1',
#  'lh_lobesStrict_R2s',
#  'lh_lobesStrict_A',
#  'lh_lobesStrict_FA',
#  'lh_lobesStrict_MD',
#  'lh_lobesStrict_L1',
#  'lh_lobesStrict_L23',
#  'lh_lobesStrict_MO',
#  'lh_Yeo2011_7Networks_N1000_MT',
#  'lh_Yeo2011_7Networks_N1000_R1',
#  'lh_Yeo2011_7Networks_N1000_R2s',
#  'lh_Yeo2011_7Networks_N1000_A',
#  'lh_Yeo2011_7Networks_N1000_FA',
#  'lh_Yeo2011_7Networks_N1000_MD',
#  'lh_Yeo2011_7Networks_N1000_L1',
#  'lh_Yeo2011_7Networks_N1000_L23',
#  'lh_Yeo2011_7Networks_N1000_MO',
#  'lh_HCP_MT',
#  'lh_HCP_R1',
#  'lh_HCP_R2s',
#  'lh_HCP_A',
#  'lh_HCP_FA',
#  'lh_HCP_MD',
#  'lh_HCP_L1',
#  'lh_HCP_L23',
#  'lh_HCP_MO',
#  'lh_economo_MT',
#  'lh_economo_R1',
#  'lh_economo_R2s',
#  'lh_economo_A',
#  'lh_economo_FA',
#  'lh_economo_MD',
#  'lh_economo_L1',
#  'lh_economo_L23',
#  'lh_economo_MO',
#  'rh_aparc_MT',
#  'rh_aparc_R1',
#  'rh_aparc_R2s',
#  'rh_aparc_A',
#  'rh_aparc_FA',
#  'rh_aparc_MD',
#  'rh_aparc_L1',
#  'rh_aparc_L23',
#  'rh_aparc_MO',
#  'rh_500.aparc_MT',
#  'rh_500.aparc_R1',
#  'rh_500.aparc_R2s',
#  'rh_500.aparc_A',
#  'rh_500.aparc_FA',
#  'rh_500.aparc_MD',
#  'rh_500.aparc_L1',
#  'rh_500.aparc_L23',
#  'rh_500.aparc_MO',
#  'rh_lobesStrict_MT',
#  'rh_lobesStrict_R1',
#  'rh_lobesStrict_R2s',
#  'rh_lobesStrict_A',
#  'rh_lobesStrict_FA',
#  'rh_lobesStrict_MD',
#  'rh_lobesStrict_L1',
#  'rh_lobesStrict_L23',
#  'rh_lobesStrict_MO',
#  'rh_Yeo2011_7Networks_N1000_MT',
#  'rh_Yeo2011_7Networks_N1000_R1',
#  'rh_Yeo2011_7Networks_N1000_R2s',
#  'rh_Yeo2011_7Networks_N1000_A',
#  'rh_Yeo2011_7Networks_N1000_FA',
#  'rh_Yeo2011_7Networks_N1000_MD',
#  'rh_Yeo2011_7Networks_N1000_L1',
#  'rh_Yeo2011_7Networks_N1000_L23',
#  'rh_Yeo2011_7Networks_N1000_MO',
#  'rh_HCP_MT',
#  'rh_HCP_R1',
#  'rh_HCP_R2s',
#  'rh_HCP_A',
#  'rh_HCP_FA',
#  'rh_HCP_MD',
#  'rh_HCP_L1',
#  'rh_HCP_L23',
#  'rh_HCP_MO',
#  'rh_economo_MT',
#  'rh_economo_R1',
#  'rh_economo_R2s',
#  'rh_economo_A',
#  'rh_economo_FA',
#  'rh_economo_MD',
#  'rh_economo_L1',
#  'rh_economo_L23',
#  'rh_economo_MO']
